# %%
import os
from xppbe.Post.results_utils import *

current_directory = os.getcwd()
path_components = current_directory.split(os.path.sep)
all_results_dir = os.path.sep.join(path_components[:-3])
all_results_dir
# Out:
# '/home/martinachondo/XPBE'

# %%
molecule = 'methanol'
results_dir = os.path.join(all_results_dir,'thesis','.saved_results',molecule)
print(results_dir)
df_filtered = create_df_excel(results_dir,'results_temp.xlsx')
# Out:
# /home/martinachondo/XPBE/thesis/.saved_results/methanol

# %%
df_filtered
# Out:
#        Gsolv_value  Loss_XPINN  Loss_NN1  Loss_NN2  Loss_Val_NN1  \
# M2          -8.505    0.000318  0.000173  0.000173      0.000172
# M4         -11.580    0.000660  0.000058  0.000058      0.000060
# M1         -11.643    0.000160  0.000008  0.000007      0.000015
# M1_NK      -11.635    0.000074  0.000003  0.000002      0.000008
# M4_NK      -11.731    0.005320  0.001165  0.001162      0.000941
# M3_NK       -8.363    0.000220  0.000016  0.000020      0.000016
# M5         -11.909    0.000604  0.000287  0.000287      0.000304
# M2_NK       -9.334    0.000270  0.000075  0.000076      0.000074
# M6         -11.580    0.000118  0.000010  0.000009      0.000010
# M5_NK      -12.056    0.000206  0.000125  0.000126      0.000127
# M6_NK      -11.738    0.000167  0.000021  0.000020      0.000019
# M3         -12.080    0.000027  0.000001  0.000001      0.000004
#
#        Loss_Val_NN2  Loss_continuity_u  Loss_continuity_du  Loss_Residual_R1  \
# M2         0.000172       5.308000e-06        1.678000e-04      1.495000e-10
# M4         0.000063       1.430000e-08        5.712000e-05      9.752000e-07
# M1         0.000010       3.045000e-08        6.966000e-06      1.204000e-06
# M1_NK      0.000004       9.271000e-09        1.784000e-06      1.333000e-06
# M4_NK      0.000939       2.871000e-07        1.161000e-03      3.878000e-06
# M3_NK      0.000020       1.437000e-06        1.442000e-05      1.996000e-07
# M5         0.000304       8.010000e-08        2.871000e-04      1.895000e-09
# M2_NK      0.000074       4.569000e-06        7.084000e-05      5.454000e-09
# M6         0.000008       1.946000e-08        8.663000e-06      1.297000e-06
# M5_NK      0.000127       7.765000e-08        1.251000e-04      7.465000e-10
# M6_NK      0.000017       1.978000e-08        1.974000e-05      1.180000e-06
# M3         0.000003       1.643000e-07        3.590000e-07      5.751000e-07
#
#        Loss_Residual_R2  Loss_Boundary_D2  Loss_Data_K2
# M2         8.939000e-13      3.072000e-08  3.502000e-08
# M4         4.023000e-07      3.662000e-09  3.484000e-09
# M1         1.557000e-07      3.203000e-09  2.522000e-09
# M1_NK      2.875000e-07      1.668000e-09  0.000000e+00
# M4_NK      1.326000e-06      6.470000e-08  0.000000e+00
# M3_NK      4.141000e-06      3.227000e-08  0.000000e+00
# M5         2.046000e-13      5.338000e-09  5.795000e-09
# M2_NK      4.899000e-12      7.908000e-07  0.000000e+00
# M6         8.698000e-08      2.515000e-09  2.369000e-09
# M5_NK      9.196000e-14      9.460000e-07  0.000000e+00
# M6_NK      1.588000e-07      4.668000e-09  0.000000e+00
# M3         5.859000e-07      8.318000e-08  8.353000e-08
